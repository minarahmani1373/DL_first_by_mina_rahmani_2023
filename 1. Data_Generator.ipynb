# %% [markdown]
# <center><img src="picture.jpg" width="600" height="500" /></center>

# %%
import tensorflow as tf
import random
import numpy as np
from tensorflow.keras.layers import concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
import tensorflow as tf
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D  
from tensorflow import keras
from tensorflow.keras import backend as K 
import os
import shutil
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# # Load data

# %%
# Define the paths to input and label data files
path_input = 'E:/Deep Course/Weeks/W10/Data/Input_data.npy'
path_label = 'E:/Deep Course/Weeks/W10/Data/Output_data.npy'

# Load input and label data from the specified files
input_data = np.load(path_input)
label_data = np.load(path_label)


print(input_data.shape)
print(label_data.shape)
# Out:
# (18545, 64, 64, 12)
# (18545, 64, 64, 1)

# %%
# Get the number of samples in the input data
n_samples = input_data.shape[0]

# Loop through each sample
for i in range(n_samples):
    # Generate a random number between 0 and 1
    random_number = random.random()

    # Check if there are any -1 values in the input or label data for the current sample
    if np.sum(input_data[i, :, :, 11] == -1) > 0 or np.sum(label_data[i, :, :, :] == -1) > 0:
        # If there are -1 values, skip this sample
        pass
    else:
        # If there are no -1 values, proceed to split the data into train and test sets

        # If the random number is less than 0.95 (95% chance), save the sample in the train set
        if random_number < 0.95:
            # Define the file names for the train set
            save_name_input = 'E:/Deep Course/Weeks/W10/Data/Train1/input_file_' + str(i) + '.npy'
            save_name_label = 'E:/Deep Course/Weeks/W10/Data/Train1/label_file_' + str(i) + '.npy'

            # Save the input and label data for the train set
            np.save(save_name_input, input_data[i, :, :, :])
            np.save(save_name_label, label_data[i, :, :, :])
        else:
            # If the random number is >= 0.95 (5% chance), save the sample in the test set
            # Define the file names for the test set
            save_name_input = 'E:/Deep Course/Weeks/W10/Data/Test1/input_file_' + str(i) + '.npy'
            save_name_label = 'E:/Deep Course/Weeks/W10/Data/Test1/label_file_' + str(i) + '.npy'

            # Save the input and label data for the test set
            np.save(save_name_input, input_data[i, :, :, :])
            np.save(save_name_label, label_data[i, :, :, :])

# %%
# Define width, height, and channel variables
width, height, channel = 64, 64, 12

# Define the directory path for training data and list files in that directory
all_files_loc_train = 'E:/Deep Course/Weeks/W10/Data/Train(without Uncertainty)/'
all_files_train = os.listdir(all_files_loc_train)

# Define the directory path for testing data and list files in that directory
all_files_loc_test = 'E:/Deep Course/Weeks/W10/Data/Test(without Uncertainty)/'
all_files_test = os.listdir(all_files_loc_test)

# Create a dictionary to map input file names to corresponding label file names for training data
image_label_map = {
    "input_file_{}.npy".format(i + 1): "label_file_{}.npy".format(i + 1)
    for i in range(int(len(all_files_train) / 2))
}

# Create a list of training data file names that contain "input" in their names
partition_train = [item for item in all_files_train if "input" in item]

# Create a dictionary to map input file names to corresponding label file names for testing data
image_label_map_val = {
    "input_file_{}.npy".format(i + 1): "label_file_{}.npy".format(i + 1)
    for i in range(int(len(all_files_test) / 2))
}

# Create a list of testing data file names that contain "input" in their names
partition_val = [item for item in all_files_test if "input" in item]

# Print information about the lengths of data sets and partitions
print('Val Len:', len(all_files_test))
print('Len Val:', len(partition_val))
print('Train Len:', len(all_files_train))
print('Len Train:', len(partition_train))
# Out:
# Val Len: 1370
# Len Val: 685
# Train Len: 19236
# Len Train: 9618

# %%
# Define a custom data generator class for training data
class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, list_examples, batch_size=4, dim=(width, height, chanel), shuffle=True):
        # Constructor of the data generator.
        self.dim = dim
        self.batch_size = batch_size
        self.list_examples = list_examples
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        # Denotes the number of batches per epoch
        return int(np.floor(len(self.list_examples) / self.batch_size))

    def __getitem__(self, index):
        # Generate one batch of data
        indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_examples[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(list_IDs_temp)

        return X, y

    def on_epoch_end(self):
        # This function is called at the end of each epoch.
        self.indexes = np.arange(len(self.list_examples))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
        # Load individual numpy arrays and aggregate them into a batch.

        X = np.empty([self.batch_size, self.dim[0], self.dim[1], self.dim[2]], dtype='float32')

        # y is a one-hot encoded vector.
        y = np.empty([self.batch_size, width, height, 1], dtype=np.float32)

        # Generate data.

        c = 0
        for i in list_IDs_temp:

            x_file_path = os.path.join(all_files_loc_train, i)
            y_file_path = os.path.join(all_files_loc_train, image_label_map.get(i))

            # Load sample
            X[c, :, :, :] = np.load(x_file_path)
            # Load labels     
            y[c, :, :, :] = np.load(y_file_path)

            c = c + 1

        return X, y

# Define a custom data generator class for validation data (similar structure to the training data generator)
class ValDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, list_examples, batch_size=4, dim=(width, height, chanel), shuffle=True):
        # Constructor of the data generator.
        self.dim = dim
        self.batch_size = batch_size
        self.list_examples = list_examples
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        # Denotes the number of batches per epoch
        return int(np.floor(len(self.list_examples) / self.batch_size))

    def __getitem__(self, index):
        # Generate one batch of data
        indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_examples[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(list_IDs_temp)

        return X, y

    def on_epoch_end(self):
        # This function is called at the end of each epoch.
        self.indexes = np.arange(len(self.list_examples))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
        # Load individual numpy arrays and aggregate them into a batch.

        X = np.empty([self.batch_size, self.dim[0], self.dim[1], self.dim[2]], dtype=np.float32)

        # y is a one-hot encoded vector.
        y = np.empty([self.batch_size, width, height, 1], dtype=np.float32)

        # Generate data.

        c = 0
        for i in list_IDs_temp:

            x_file_path = os.path.join(all_files_loc_test, i)
            y_file_path = os.path.join(all_files_loc_test, image_label_map_val.get(i))

            # Load sample
            X[c, :, :, :] = np.load(x_file_path)
            # Load labels     
            y[c, :, :, :] = np.load(y_file_path)

            c = c + 1

        return X, y

# Create instances of the custom data generators for training and validation data
training_generator = DataGenerator(partition_train)
validation_generator = ValDataGenerator(partition_val)

# %%
# Define constants ALPHA and BETA
ALPHA = 0.7
BETA = 0.3

# Define TverskyLoss function
def TverskyLoss(targets, inputs, alpha=ALPHA, beta=BETA, smooth=1e-6):
    """
    Tversky Loss function for semantic segmentation.
    :param targets: Ground truth labels
    :param inputs: Predicted labels
    :param alpha: Weight for false positives
    :param beta: Weight for false negatives
    :param smooth: Smoothing term to prevent division by zero
    :return: Tversky loss value
    """
    # Flatten label and prediction tensors
    inputs = K.flatten(inputs)
    targets = K.flatten(targets)
    
    # Calculate True Positives, False Positives & False Negatives
    TP = K.sum((inputs * targets))
    FP = K.sum(((1 - targets) * inputs))
    FN = K.sum((targets * (1 - inputs)))
    
    # Calculate Tversky score
    Tversky = (TP + smooth) / (TP + alpha * FP + beta * FN + smooth)
    
    # Return Tversky loss
    return (1 - Tversky)

# Define Intersection over Union (IoU) function
def iou(y_true, y_pred, smooth=1):
    """
    Intersection over Union (IoU) metric for semantic segmentation.
    :param y_true: Ground truth labels
    :param y_pred: Predicted labels
    :param smooth: Smoothing term to prevent division by zero
    :return: IoU score
    """
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# Define Jaccard distance function
def jac_distance(y_true, y_pred):
    """
    Jaccard Distance (1 - IoU) metric for semantic segmentation.
    :param y_true: Ground truth labels
    :param y_pred: Predicted labels
    :return: Jaccard distance
    """
    y_truef = K.flatten(y_true)
    y_predf = K.flatten(y_pred)
    
    return -iou(y_true, y_pred)

# %%
# Define a custom convolutional neural network model
def Model_(input_shape):
    # Define the input layer with the specified input shape
    input_ = Input(input_shape)
    
   
    x1 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(.00001))(input_)
    x1 = Conv2D(128, (3, 3), kernel_regularizer=regularizers.l2(.00001), padding='same')(x1)
    
     # Define a series of convolutional layers with different dilation rates
    x2 = Conv2D(64, (3, 3), dilation_rate=3, activation='relu', padding='same')(x1)
    x3 = Conv2D(66, (3, 3), dilation_rate=6, activation='relu', padding='same')(x1)    
    x4 = Conv2D(64, (3, 3), dilation_rate=12, activation='relu', padding='same')(x1)
    x5 = Conv2D(64, (3, 3), dilation_rate=18, activation='relu', padding='same')(x1)
    x6 = Conv2D(64, (3, 3), dilation_rate=1, activation='relu', padding='same')(x1)
    
    # Concatenate the output feature maps from the convolutional layers
    x6 = concatenate([x6, x5, x2, x3, x4])

    # Apply additional convolutional layers
    x7 = Conv2D(32, (1, 1), padding='same')(x6)
    x8 = Conv2D(32, (3, 3), padding='same')(x7) 
    x9 = Conv2D(16, (3, 3), padding='same')(x8)
  
    # Apply batch normalization
    x10 = BatchNormalization()(x9)
    
    # Define the output layer with sigmoid activation
    output = Conv2D(1, (1, 1), padding='same', activation='sigmoid')(x10)
    
    # Create and return the Keras model
    return Model(inputs=input_, outputs=output)

# Create an instance of the custom model with the specified input shape
model = Model_((width, height, chanel))

# Print a summary of the model architecture
model.summary()
# Out:
# Model: "model_19"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_20 (InputLayer)           [(None, 64, 64, 12)] 0
# __________________________________________________________________________________________________
# conv2d_209 (Conv2D)             (None, 64, 64, 64)   6976        input_20[0][0]
# __________________________________________________________________________________________________
# conv2d_210 (Conv2D)             (None, 64, 64, 128)  73856       conv2d_209[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 64, 64, 64)   73792       conv2d_210[0][0]
# __________________________________________________________________________________________________
# conv2d_214 (Conv2D)             (None, 64, 64, 64)   73792       conv2d_210[0][0]
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 64, 64, 64)   73792       conv2d_210[0][0]
# __________________________________________________________________________________________________
# conv2d_212 (Conv2D)             (None, 64, 64, 66)   76098       conv2d_210[0][0]
# __________________________________________________________________________________________________
# conv2d_213 (Conv2D)             (None, 64, 64, 64)   73792       conv2d_210[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 64, 64, 322)  0           conv2d_215[0][0]
#                                                                  conv2d_214[0][0]
#                                                                  conv2d_211[0][0]
#                                                                  conv2d_212[0][0]
#                                                                  conv2d_213[0][0]
# __________________________________________________________________________________________________
# conv2d_216 (Conv2D)             (None, 64, 64, 32)   10336       concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 64, 64, 32)   9248        conv2d_216[0][0]
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 64, 64, 16)   4624        conv2d_217[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 64, 64, 16)   64          conv2d_218[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 64, 64, 1)    17          batch_normalization_19[0][0]
# ==================================================================================================
# Total params: 476,387
# Trainable params: 476,355
# Non-trainable params: 32
# __________________________________________________________________________________________________

# %%
# Create an instance of the custom neural network model with the specified input shape
model = Model_((width, height, chanel))

# Define the learning rate for the optimizer
learning_rate = 0.0005

# Define the optimizer (RMSprop in this case) with the specified learning rate
optimizer = tf.keras.optimizers.RMSprop(learning_rate=learning_rate)

# Compile the model with a custom loss function (TverskyLoss) and metrics (IoU)
model.compile(loss=TverskyLoss, optimizer=optimizer, metrics=[iou])

# Define an early stopping callback to monitor validation loss and stop training if it doesn't improve for a certain number of epochs
early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=60)

# Create a list of callbacks, including ModelCheckpoint to save the best model and EarlyStopping for early stopping
callbacks = [ModelCheckpoint('E:/Deep Course/Weeks/W10/Models/model-200MC.h5',
                             verbose=1, save_best_only=True), early_stopping]

# %%
history =model.fit(training_generator,epochs=500,validation_data=validation_generator,callbacks=callbacks)
# Out:
# Epoch 1/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.7646 - iou: 0.1544 - val_loss: 0.7245 - val_iou: 0.1805
#
# Epoch 00001: val_loss improved from inf to 0.72451, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 2/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.6782 - iou: 0.2003 - val_loss: 0.6644 - val_iou: 0.2029
#
# Epoch 00002: val_loss improved from 0.72451 to 0.66438, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 3/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.6719 - iou: 0.2016 - val_loss: 0.6848 - val_iou: 0.1882
#
# Epoch 00003: val_loss did not improve from 0.66438
# Epoch 4/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.6644 - iou: 0.2094 - val_loss: 0.6661 - val_iou: 0.2020
#
# Epoch 00004: val_loss did not improve from 0.66438
# Epoch 5/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.6601 - iou: 0.2128 - val_loss: 0.6766 - val_iou: 0.1943
#
# Epoch 00005: val_loss did not improve from 0.66438
# Epoch 6/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.6606 - iou: 0.2132 - val_loss: 0.6588 - val_iou: 0.2090
#
# Epoch 00006: val_loss improved from 0.66438 to 0.65881, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 7/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.6558 - iou: 0.2159 - val_loss: 0.6767 - val_iou: 0.1930
#
# Epoch 00007: val_loss did not improve from 0.65881
# Epoch 8/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.6526 - iou: 0.2184 - val_loss: 0.6581 - val_iou: 0.2071
#
# Epoch 00008: val_loss improved from 0.65881 to 0.65813, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 9/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.6476 - iou: 0.2217 - val_loss: 0.6514 - val_iou: 0.2187
#
# Epoch 00009: val_loss improved from 0.65813 to 0.65145, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 10/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.6478 - iou: 0.2209 - val_loss: 0.6754 - val_iou: 0.1911
#
# Epoch 00010: val_loss did not improve from 0.65145
# Epoch 11/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.6410 - iou: 0.2253 - val_loss: 0.6535 - val_iou: 0.2098
#
# Epoch 00011: val_loss did not improve from 0.65145
# Epoch 12/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.6405 - iou: 0.2254 - val_loss: 0.6622 - val_iou: 0.2105
#
# Epoch 00012: val_loss did not improve from 0.65145
# Epoch 13/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.6384 - iou: 0.2273 - val_loss: 0.6510 - val_iou: 0.2133
#
# Epoch 00013: val_loss improved from 0.65145 to 0.65098, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 14/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.6341 - iou: 0.2297 - val_loss: 0.6460 - val_iou: 0.2199
#
# Epoch 00014: val_loss improved from 0.65098 to 0.64597, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 15/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.6334 - iou: 0.2311 - val_loss: 0.6391 - val_iou: 0.2147
#
# Epoch 00015: val_loss improved from 0.64597 to 0.63905, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 16/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.6328 - iou: 0.2299 - val_loss: 0.6550 - val_iou: 0.2064
#
# Epoch 00016: val_loss did not improve from 0.63905
# Epoch 17/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.6309 - iou: 0.2322 - val_loss: 0.6495 - val_iou: 0.2198
#
# Epoch 00017: val_loss did not improve from 0.63905
# Epoch 18/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.6241 - iou: 0.2365 - val_loss: 0.6529 - val_iou: 0.2141
#
# Epoch 00018: val_loss did not improve from 0.63905
# Epoch 19/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.6199 - iou: 0.2394 - val_loss: 0.6448 - val_iou: 0.2173
#
# Epoch 00019: val_loss did not improve from 0.63905
# Epoch 20/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.6194 - iou: 0.2402 - val_loss: 0.6303 - val_iou: 0.2319
#
# Epoch 00020: val_loss improved from 0.63905 to 0.63032, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 21/500
# 2404/2404 [==============================] - 124s 52ms/step - loss: 0.6164 - iou: 0.2424 - val_loss: 0.6259 - val_iou: 0.2314
#
# Epoch 00021: val_loss improved from 0.63032 to 0.62586, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 22/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.6111 - iou: 0.2457 - val_loss: 0.6402 - val_iou: 0.2163
#
# Epoch 00022: val_loss did not improve from 0.62586
# Epoch 23/500
# 2404/2404 [==============================] - 150s 62ms/step - loss: 0.6058 - iou: 0.2483 - val_loss: 0.6347 - val_iou: 0.2290
#
# Epoch 00023: val_loss did not improve from 0.62586
# Epoch 24/500
# 2404/2404 [==============================] - 131s 54ms/step - loss: 0.6003 - iou: 0.2534 - val_loss: 0.6191 - val_iou: 0.2285
#
# Epoch 00024: val_loss improved from 0.62586 to 0.61908, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 25/500
# 2404/2404 [==============================] - 131s 54ms/step - loss: 0.5982 - iou: 0.2547 - val_loss: 0.6081 - val_iou: 0.2374
#
# Epoch 00025: val_loss improved from 0.61908 to 0.60808, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 26/500
# 2404/2404 [==============================] - 126s 52ms/step - loss: 0.5973 - iou: 0.2558 - val_loss: 0.6271 - val_iou: 0.2240
#
# Epoch 00026: val_loss did not improve from 0.60808
# Epoch 27/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.5892 - iou: 0.2602 - val_loss: 0.6148 - val_iou: 0.2346
#
# Epoch 00027: val_loss did not improve from 0.60808
# Epoch 28/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.5871 - iou: 0.2628 - val_loss: 0.6126 - val_iou: 0.2448
#
# Epoch 00028: val_loss did not improve from 0.60808
# Epoch 29/500
# 2404/2404 [==============================] - 124s 51ms/step - loss: 0.5825 - iou: 0.2658 - val_loss: 0.6006 - val_iou: 0.2490
#
# Epoch 00029: val_loss improved from 0.60808 to 0.60055, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 30/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.5780 - iou: 0.2691 - val_loss: 0.6013 - val_iou: 0.2477
#
# Epoch 00030: val_loss did not improve from 0.60055
# Epoch 31/500
# 2404/2404 [==============================] - 124s 52ms/step - loss: 0.5714 - iou: 0.2736 - val_loss: 0.6001 - val_iou: 0.2496
#
# Epoch 00031: val_loss improved from 0.60055 to 0.60008, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 32/500
# 2404/2404 [==============================] - 134s 56ms/step - loss: 0.5691 - iou: 0.2749 - val_loss: 0.5915 - val_iou: 0.2551
#
# Epoch 00032: val_loss improved from 0.60008 to 0.59148, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 33/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.5613 - iou: 0.2801 - val_loss: 0.5819 - val_iou: 0.2537
#
# Epoch 00033: val_loss improved from 0.59148 to 0.58190, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 34/500
# 2404/2404 [==============================] - 125s 52ms/step - loss: 0.5604 - iou: 0.2814 - val_loss: 0.5989 - val_iou: 0.2445
#
# Epoch 00034: val_loss did not improve from 0.58190
# Epoch 35/500
# 2404/2404 [==============================] - 127s 53ms/step - loss: 0.5548 - iou: 0.2852 - val_loss: 0.5902 - val_iou: 0.2639
#
# Epoch 00035: val_loss did not improve from 0.58190
# Epoch 36/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.5502 - iou: 0.2887 - val_loss: 0.5901 - val_iou: 0.2561
#
# Epoch 00036: val_loss did not improve from 0.58190
# Epoch 37/500
# 2404/2404 [==============================] - 121s 51ms/step - loss: 0.5434 - iou: 0.2929 - val_loss: 0.5974 - val_iou: 0.2420
#
# Epoch 00037: val_loss did not improve from 0.58190
# Epoch 38/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.5412 - iou: 0.2946 - val_loss: 0.5639 - val_iou: 0.2733
#
# Epoch 00038: val_loss improved from 0.58190 to 0.56388, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 39/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.5346 - iou: 0.2993 - val_loss: 0.5721 - val_iou: 0.2694
#
# Epoch 00039: val_loss did not improve from 0.56388
# Epoch 40/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.5314 - iou: 0.3026 - val_loss: 0.5759 - val_iou: 0.2620
#
# Epoch 00040: val_loss did not improve from 0.56388
# Epoch 41/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.5301 - iou: 0.3036 - val_loss: 0.5729 - val_iou: 0.2716
#
# Epoch 00041: val_loss did not improve from 0.56388
# Epoch 42/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.5248 - iou: 0.3074 - val_loss: 0.5735 - val_iou: 0.2723
#
# Epoch 00042: val_loss did not improve from 0.56388
# Epoch 43/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.5238 - iou: 0.3080 - val_loss: 0.5680 - val_iou: 0.2697
#
# Epoch 00043: val_loss did not improve from 0.56388
# Epoch 44/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.5203 - iou: 0.3113 - val_loss: 0.5673 - val_iou: 0.2864
#
# Epoch 00044: val_loss did not improve from 0.56388
# Epoch 45/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.5129 - iou: 0.3162 - val_loss: 0.5645 - val_iou: 0.2668
#
# Epoch 00045: val_loss did not improve from 0.56388
# Epoch 46/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.5110 - iou: 0.3180 - val_loss: 0.5582 - val_iou: 0.2774
#
# Epoch 00046: val_loss improved from 0.56388 to 0.55821, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 47/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.5038 - iou: 0.3227 - val_loss: 0.5691 - val_iou: 0.2680
#
# Epoch 00047: val_loss did not improve from 0.55821
# Epoch 48/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.5024 - iou: 0.3241 - val_loss: 0.5506 - val_iou: 0.2849
#
# Epoch 00048: val_loss improved from 0.55821 to 0.55057, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 49/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4943 - iou: 0.3300 - val_loss: 0.5615 - val_iou: 0.2803
#
# Epoch 00049: val_loss did not improve from 0.55057
# Epoch 50/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4967 - iou: 0.3287 - val_loss: 0.5536 - val_iou: 0.2762
#
# Epoch 00050: val_loss did not improve from 0.55057
# Epoch 51/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4917 - iou: 0.3326 - val_loss: 0.5382 - val_iou: 0.3002
#
# Epoch 00051: val_loss improved from 0.55057 to 0.53818, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 52/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4896 - iou: 0.3346 - val_loss: 0.5407 - val_iou: 0.2960
#
# Epoch 00052: val_loss did not improve from 0.53818
# Epoch 53/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4858 - iou: 0.3363 - val_loss: 0.5522 - val_iou: 0.2900
#
# Epoch 00053: val_loss did not improve from 0.53818
# Epoch 54/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4798 - iou: 0.3430 - val_loss: 0.5543 - val_iou: 0.2724
#
# Epoch 00054: val_loss did not improve from 0.53818
# Epoch 55/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.4771 - iou: 0.3452 - val_loss: 0.5622 - val_iou: 0.2665
#
# Epoch 00055: val_loss did not improve from 0.53818
# Epoch 56/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.4789 - iou: 0.3435 - val_loss: 0.5203 - val_iou: 0.3072
#
# Epoch 00056: val_loss improved from 0.53818 to 0.52035, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 57/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.4733 - iou: 0.3489 - val_loss: 0.5401 - val_iou: 0.2907
#
# Epoch 00057: val_loss did not improve from 0.52035
# Epoch 58/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.4750 - iou: 0.3488 - val_loss: 0.5352 - val_iou: 0.2957
#
# Epoch 00058: val_loss did not improve from 0.52035
# Epoch 59/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4647 - iou: 0.3543 - val_loss: 0.5302 - val_iou: 0.3054
#
# Epoch 00059: val_loss did not improve from 0.52035
# Epoch 60/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4663 - iou: 0.3548 - val_loss: 0.5164 - val_iou: 0.3143
#
# Epoch 00060: val_loss improved from 0.52035 to 0.51642, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 61/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4656 - iou: 0.3549 - val_loss: 0.5281 - val_iou: 0.2996
#
# Epoch 00061: val_loss did not improve from 0.51642
# Epoch 62/500
# 2404/2404 [==============================] - 154s 64ms/step - loss: 0.4629 - iou: 0.3569 - val_loss: 0.5154 - val_iou: 0.3055
#
# Epoch 00062: val_loss improved from 0.51642 to 0.51543, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 63/500
# 2404/2404 [==============================] - 125s 52ms/step - loss: 0.4580 - iou: 0.3615 - val_loss: 0.5205 - val_iou: 0.3042
#
# Epoch 00063: val_loss did not improve from 0.51543
# Epoch 64/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4568 - iou: 0.3616 - val_loss: 0.5390 - val_iou: 0.3000
#
# Epoch 00064: val_loss did not improve from 0.51543
# Epoch 65/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4518 - iou: 0.3661 - val_loss: 0.5244 - val_iou: 0.3007
#
# Epoch 00065: val_loss did not improve from 0.51543
# Epoch 66/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4491 - iou: 0.3684 - val_loss: 0.5257 - val_iou: 0.2907
#
# Epoch 00066: val_loss did not improve from 0.51543
# Epoch 67/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4473 - iou: 0.3695 - val_loss: 0.5223 - val_iou: 0.3167
#
# Epoch 00067: val_loss did not improve from 0.51543
# Epoch 68/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4436 - iou: 0.3730 - val_loss: 0.5184 - val_iou: 0.3155
#
# Epoch 00068: val_loss did not improve from 0.51543
# Epoch 69/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.4429 - iou: 0.3746 - val_loss: 0.4914 - val_iou: 0.3340
#
# Epoch 00069: val_loss improved from 0.51543 to 0.49145, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 70/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4409 - iou: 0.3752 - val_loss: 0.5174 - val_iou: 0.3112
#
# Epoch 00070: val_loss did not improve from 0.49145
# Epoch 71/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4438 - iou: 0.3736 - val_loss: 0.5114 - val_iou: 0.3070
#
# Epoch 00071: val_loss did not improve from 0.49145
# Epoch 72/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.4403 - iou: 0.3768 - val_loss: 0.5127 - val_iou: 0.3234
#
# Epoch 00072: val_loss did not improve from 0.49145
# Epoch 73/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.4351 - iou: 0.3815 - val_loss: 0.5266 - val_iou: 0.3077
#
# Epoch 00073: val_loss did not improve from 0.49145
# Epoch 74/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.4350 - iou: 0.3816 - val_loss: 0.5432 - val_iou: 0.2906
#
# Epoch 00074: val_loss did not improve from 0.49145
# Epoch 75/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.4312 - iou: 0.3844 - val_loss: 0.5193 - val_iou: 0.3025
#
# Epoch 00075: val_loss did not improve from 0.49145
# Epoch 76/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4282 - iou: 0.3862 - val_loss: 0.4963 - val_iou: 0.3353
#
# Epoch 00076: val_loss did not improve from 0.49145
# Epoch 77/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4283 - iou: 0.3867 - val_loss: 0.5065 - val_iou: 0.3128
#
# Epoch 00077: val_loss did not improve from 0.49145
# Epoch 78/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4242 - iou: 0.3894 - val_loss: 0.5045 - val_iou: 0.3287
#
# Epoch 00078: val_loss did not improve from 0.49145
# Epoch 79/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4288 - iou: 0.3884 - val_loss: 0.5123 - val_iou: 0.3310
#
# Epoch 00079: val_loss did not improve from 0.49145
# Epoch 80/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4219 - iou: 0.3929 - val_loss: 0.4902 - val_iou: 0.3346
#
# Epoch 00080: val_loss improved from 0.49145 to 0.49025, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 81/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4245 - iou: 0.3922 - val_loss: 0.4951 - val_iou: 0.3260
#
# Epoch 00081: val_loss did not improve from 0.49025
# Epoch 82/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4195 - iou: 0.3958 - val_loss: 0.5053 - val_iou: 0.3241
#
# Epoch 00082: val_loss did not improve from 0.49025
# Epoch 83/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4206 - iou: 0.3952 - val_loss: 0.5021 - val_iou: 0.3241
#
# Epoch 00083: val_loss did not improve from 0.49025
# Epoch 84/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4150 - iou: 0.3980 - val_loss: 0.5078 - val_iou: 0.3204
#
# Epoch 00084: val_loss did not improve from 0.49025
# Epoch 85/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4122 - iou: 0.4006 - val_loss: 0.4948 - val_iou: 0.3328
#
# Epoch 00085: val_loss did not improve from 0.49025
# Epoch 86/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4160 - iou: 0.3989 - val_loss: 0.4728 - val_iou: 0.3378
#
# Epoch 00086: val_loss improved from 0.49025 to 0.47281, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 87/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4120 - iou: 0.4023 - val_loss: 0.4938 - val_iou: 0.3396
#
# Epoch 00087: val_loss did not improve from 0.47281
# Epoch 88/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4122 - iou: 0.4016 - val_loss: 0.5169 - val_iou: 0.3112
#
# Epoch 00088: val_loss did not improve from 0.47281
# Epoch 89/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4068 - iou: 0.4067 - val_loss: 0.4851 - val_iou: 0.3438
#
# Epoch 00089: val_loss did not improve from 0.47281
# Epoch 90/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4053 - iou: 0.4081 - val_loss: 0.4977 - val_iou: 0.3247
#
# Epoch 00090: val_loss did not improve from 0.47281
# Epoch 91/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4052 - iou: 0.4075 - val_loss: 0.4856 - val_iou: 0.3446
#
# Epoch 00091: val_loss did not improve from 0.47281
# Epoch 92/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4055 - iou: 0.4091 - val_loss: 0.4903 - val_iou: 0.3399
#
# Epoch 00092: val_loss did not improve from 0.47281
# Epoch 93/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.4078 - iou: 0.4079 - val_loss: 0.4844 - val_iou: 0.3365
#
# Epoch 00093: val_loss did not improve from 0.47281
# Epoch 94/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4022 - iou: 0.4119 - val_loss: 0.4919 - val_iou: 0.3295
#
# Epoch 00094: val_loss did not improve from 0.47281
# Epoch 95/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4003 - iou: 0.4117 - val_loss: 0.4812 - val_iou: 0.3379
#
# Epoch 00095: val_loss did not improve from 0.47281
# Epoch 96/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4015 - iou: 0.4122 - val_loss: 0.4803 - val_iou: 0.3413
#
# Epoch 00096: val_loss did not improve from 0.47281
# Epoch 97/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.3975 - iou: 0.4161 - val_loss: 0.4791 - val_iou: 0.3497
#
# Epoch 00097: val_loss did not improve from 0.47281
# Epoch 98/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.4002 - iou: 0.4129 - val_loss: 0.4775 - val_iou: 0.3444
#
# Epoch 00098: val_loss did not improve from 0.47281
# Epoch 99/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.3931 - iou: 0.4181 - val_loss: 0.4889 - val_iou: 0.3362
#
# Epoch 00099: val_loss did not improve from 0.47281
# Epoch 100/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.3979 - iou: 0.4169 - val_loss: 0.4982 - val_iou: 0.3257
#
# Epoch 00100: val_loss did not improve from 0.47281
# Epoch 101/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.3970 - iou: 0.4173 - val_loss: 0.4708 - val_iou: 0.3418
#
# Epoch 00101: val_loss improved from 0.47281 to 0.47076, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 102/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.3916 - iou: 0.4202 - val_loss: 0.4877 - val_iou: 0.3319
#
# Epoch 00102: val_loss did not improve from 0.47076
# Epoch 103/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.3941 - iou: 0.4207 - val_loss: 0.4818 - val_iou: 0.3415
#
# Epoch 00103: val_loss did not improve from 0.47076
# Epoch 104/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3914 - iou: 0.4211 - val_loss: 0.4865 - val_iou: 0.3386
#
# Epoch 00104: val_loss did not improve from 0.47076
# Epoch 105/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3919 - iou: 0.4222 - val_loss: 0.4695 - val_iou: 0.3502
#
# Epoch 00105: val_loss improved from 0.47076 to 0.46947, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 106/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3916 - iou: 0.4228 - val_loss: 0.4761 - val_iou: 0.3527
#
# Epoch 00106: val_loss did not improve from 0.46947
# Epoch 107/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3885 - iou: 0.4265 - val_loss: 0.4926 - val_iou: 0.3449
#
# Epoch 00107: val_loss did not improve from 0.46947
# Epoch 108/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3850 - iou: 0.4278 - val_loss: 0.4873 - val_iou: 0.3500
#
# Epoch 00108: val_loss did not improve from 0.46947
# Epoch 109/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3896 - iou: 0.4250 - val_loss: 0.4808 - val_iou: 0.3404
#
# Epoch 00109: val_loss did not improve from 0.46947
# Epoch 110/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3911 - iou: 0.4255 - val_loss: 0.4913 - val_iou: 0.3310
#
# Epoch 00110: val_loss did not improve from 0.46947
# Epoch 111/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3856 - iou: 0.4282 - val_loss: 0.4763 - val_iou: 0.3496
#
# Epoch 00111: val_loss did not improve from 0.46947
# Epoch 112/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3870 - iou: 0.4277 - val_loss: 0.4791 - val_iou: 0.3425
#
# Epoch 00112: val_loss did not improve from 0.46947
# Epoch 113/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3800 - iou: 0.4324 - val_loss: 0.4673 - val_iou: 0.3495
#
# Epoch 00113: val_loss improved from 0.46947 to 0.46727, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 114/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3843 - iou: 0.4303 - val_loss: 0.4869 - val_iou: 0.3365
#
# Epoch 00114: val_loss did not improve from 0.46727
# Epoch 115/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3810 - iou: 0.4322 - val_loss: 0.4767 - val_iou: 0.3457
#
# Epoch 00115: val_loss did not improve from 0.46727
# Epoch 116/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3836 - iou: 0.4316 - val_loss: 0.4766 - val_iou: 0.3497
#
# Epoch 00116: val_loss did not improve from 0.46727
# Epoch 117/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3802 - iou: 0.4343 - val_loss: 0.4833 - val_iou: 0.3416
#
# Epoch 00117: val_loss did not improve from 0.46727
# Epoch 118/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3777 - iou: 0.4360 - val_loss: 0.4689 - val_iou: 0.3570
#
# Epoch 00118: val_loss did not improve from 0.46727
# Epoch 119/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3778 - iou: 0.4358 - val_loss: 0.4740 - val_iou: 0.3584
#
# Epoch 00119: val_loss did not improve from 0.46727
# Epoch 120/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3744 - iou: 0.4391 - val_loss: 0.4723 - val_iou: 0.3451
#
# Epoch 00120: val_loss did not improve from 0.46727
# Epoch 121/500
# 2404/2404 [==============================] - 124s 51ms/step - loss: 0.3742 - iou: 0.4383 - val_loss: 0.4769 - val_iou: 0.3449
#
# Epoch 00121: val_loss did not improve from 0.46727
# Epoch 122/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3689 - iou: 0.4429 - val_loss: 0.4615 - val_iou: 0.3666
#
# Epoch 00122: val_loss improved from 0.46727 to 0.46152, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 123/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3686 - iou: 0.4435 - val_loss: 0.4574 - val_iou: 0.3626
#
# Epoch 00123: val_loss improved from 0.46152 to 0.45738, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 124/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3750 - iou: 0.4397 - val_loss: 0.4719 - val_iou: 0.3466
#
# Epoch 00124: val_loss did not improve from 0.45738
# Epoch 125/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3701 - iou: 0.4426 - val_loss: 0.4716 - val_iou: 0.3513
#
# Epoch 00125: val_loss did not improve from 0.45738
# Epoch 126/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3680 - iou: 0.4438 - val_loss: 0.4764 - val_iou: 0.3586
#
# Epoch 00126: val_loss did not improve from 0.45738
# Epoch 127/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3708 - iou: 0.4436 - val_loss: 0.4529 - val_iou: 0.3688
#
# Epoch 00127: val_loss improved from 0.45738 to 0.45286, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 128/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3665 - iou: 0.4456 - val_loss: 0.4501 - val_iou: 0.3740
#
# Epoch 00128: val_loss improved from 0.45286 to 0.45011, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 129/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3655 - iou: 0.4464 - val_loss: 0.4669 - val_iou: 0.3625
#
# Epoch 00129: val_loss did not improve from 0.45011
# Epoch 130/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3676 - iou: 0.4470 - val_loss: 0.4690 - val_iou: 0.3582
#
# Epoch 00130: val_loss did not improve from 0.45011
# Epoch 131/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3654 - iou: 0.4468 - val_loss: 0.4739 - val_iou: 0.3530
#
# Epoch 00131: val_loss did not improve from 0.45011
# Epoch 132/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3668 - iou: 0.4478 - val_loss: 0.4789 - val_iou: 0.3438
#
# Epoch 00132: val_loss did not improve from 0.45011
# Epoch 133/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3621 - iou: 0.4512 - val_loss: 0.4652 - val_iou: 0.3725
#
# Epoch 00133: val_loss did not improve from 0.45011
# Epoch 134/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3654 - iou: 0.4485 - val_loss: 0.4607 - val_iou: 0.3744
#
# Epoch 00134: val_loss did not improve from 0.45011
# Epoch 135/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3631 - iou: 0.4502 - val_loss: 0.4742 - val_iou: 0.3546
#
# Epoch 00135: val_loss did not improve from 0.45011
# Epoch 136/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3648 - iou: 0.4487 - val_loss: 0.4455 - val_iou: 0.3816
#
# Epoch 00136: val_loss improved from 0.45011 to 0.44553, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 137/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3632 - iou: 0.4511 - val_loss: 0.4602 - val_iou: 0.3683
#
# Epoch 00137: val_loss did not improve from 0.44553
# Epoch 138/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3649 - iou: 0.4502 - val_loss: 0.4601 - val_iou: 0.3701
#
# Epoch 00138: val_loss did not improve from 0.44553
# Epoch 139/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3628 - iou: 0.4533 - val_loss: 0.4514 - val_iou: 0.3625
#
# Epoch 00139: val_loss did not improve from 0.44553
# Epoch 140/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3557 - iou: 0.4582 - val_loss: 0.4756 - val_iou: 0.3470
#
# Epoch 00140: val_loss did not improve from 0.44553
# Epoch 141/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3635 - iou: 0.4513 - val_loss: 0.4648 - val_iou: 0.3632
#
# Epoch 00141: val_loss did not improve from 0.44553
# Epoch 142/500
# 2404/2404 [==============================] - 125s 52ms/step - loss: 0.3594 - iou: 0.4553 - val_loss: 0.4754 - val_iou: 0.3491
#
# Epoch 00142: val_loss did not improve from 0.44553
# Epoch 143/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3638 - iou: 0.4523 - val_loss: 0.4540 - val_iou: 0.3687
#
# Epoch 00143: val_loss did not improve from 0.44553
# Epoch 144/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3602 - iou: 0.4545 - val_loss: 0.4524 - val_iou: 0.3658
#
# Epoch 00144: val_loss did not improve from 0.44553
# Epoch 145/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3571 - iou: 0.4586 - val_loss: 0.4660 - val_iou: 0.3632
#
# Epoch 00145: val_loss did not improve from 0.44553
# Epoch 146/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3516 - iou: 0.4609 - val_loss: 0.4588 - val_iou: 0.3646
#
# Epoch 00146: val_loss did not improve from 0.44553
# Epoch 147/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3541 - iou: 0.4594 - val_loss: 0.4528 - val_iou: 0.3722
#
# Epoch 00147: val_loss did not improve from 0.44553
# Epoch 148/500
# 2404/2404 [==============================] - 124s 52ms/step - loss: 0.3520 - iou: 0.4610 - val_loss: 0.4533 - val_iou: 0.3712
#
# Epoch 00148: val_loss did not improve from 0.44553
# Epoch 149/500
# 2404/2404 [==============================] - 124s 52ms/step - loss: 0.3528 - iou: 0.4615 - val_loss: 0.4727 - val_iou: 0.3558
#
# Epoch 00149: val_loss did not improve from 0.44553
# Epoch 150/500
# 2404/2404 [==============================] - 124s 52ms/step - loss: 0.3536 - iou: 0.4609 - val_loss: 0.4517 - val_iou: 0.3748
#
# Epoch 00150: val_loss did not improve from 0.44553
# Epoch 151/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3510 - iou: 0.4624 - val_loss: 0.4530 - val_iou: 0.3700
#
# Epoch 00151: val_loss did not improve from 0.44553
# Epoch 152/500
# 2404/2404 [==============================] - 124s 51ms/step - loss: 0.3497 - iou: 0.4637 - val_loss: 0.4689 - val_iou: 0.3727
#
# Epoch 00152: val_loss did not improve from 0.44553
# Epoch 153/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3520 - iou: 0.4626 - val_loss: 0.4582 - val_iou: 0.3765
#
# Epoch 00153: val_loss did not improve from 0.44553
# Epoch 154/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3477 - iou: 0.4668 - val_loss: 0.4546 - val_iou: 0.3748
#
# Epoch 00154: val_loss did not improve from 0.44553
# Epoch 155/500
# 2404/2404 [==============================] - 124s 51ms/step - loss: 0.3490 - iou: 0.4650 - val_loss: 0.4491 - val_iou: 0.3698
#
# Epoch 00155: val_loss did not improve from 0.44553
# Epoch 156/500
# 2404/2404 [==============================] - 125s 52ms/step - loss: 0.3504 - iou: 0.4645 - val_loss: 0.4453 - val_iou: 0.3776
#
# Epoch 00156: val_loss improved from 0.44553 to 0.44533, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 157/500
# 2404/2404 [==============================] - 124s 52ms/step - loss: 0.3509 - iou: 0.4635 - val_loss: 0.4608 - val_iou: 0.3653
#
# Epoch 00157: val_loss did not improve from 0.44533
# Epoch 158/500
# 2404/2404 [==============================] - 124s 52ms/step - loss: 0.3504 - iou: 0.4646 - val_loss: 0.4428 - val_iou: 0.3884
#
# Epoch 00158: val_loss improved from 0.44533 to 0.44281, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 159/500
# 2404/2404 [==============================] - 124s 51ms/step - loss: 0.3468 - iou: 0.4677 - val_loss: 0.4509 - val_iou: 0.3772
#
# Epoch 00159: val_loss did not improve from 0.44281
# Epoch 160/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3426 - iou: 0.4710 - val_loss: 0.4741 - val_iou: 0.3512
#
# Epoch 00160: val_loss did not improve from 0.44281
# Epoch 161/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3471 - iou: 0.4683 - val_loss: 0.4381 - val_iou: 0.3794
#
# Epoch 00161: val_loss improved from 0.44281 to 0.43805, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 162/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3439 - iou: 0.4691 - val_loss: 0.4391 - val_iou: 0.3847
#
# Epoch 00162: val_loss did not improve from 0.43805
# Epoch 163/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3468 - iou: 0.4693 - val_loss: 0.4537 - val_iou: 0.3751
#
# Epoch 00163: val_loss did not improve from 0.43805
# Epoch 164/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3465 - iou: 0.4708 - val_loss: 0.4431 - val_iou: 0.3761
#
# Epoch 00164: val_loss did not improve from 0.43805
# Epoch 165/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3460 - iou: 0.4707 - val_loss: 0.4618 - val_iou: 0.3692
#
# Epoch 00165: val_loss did not improve from 0.43805
# Epoch 166/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3453 - iou: 0.4708 - val_loss: 0.4782 - val_iou: 0.3462
#
# Epoch 00166: val_loss did not improve from 0.43805
# Epoch 167/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3467 - iou: 0.4687 - val_loss: 0.4430 - val_iou: 0.3882
#
# Epoch 00167: val_loss did not improve from 0.43805
# Epoch 168/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3423 - iou: 0.4720 - val_loss: 0.4492 - val_iou: 0.3754
#
# Epoch 00168: val_loss did not improve from 0.43805
# Epoch 169/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3442 - iou: 0.4727 - val_loss: 0.4435 - val_iou: 0.3743
#
# Epoch 00169: val_loss did not improve from 0.43805
# Epoch 170/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3437 - iou: 0.4717 - val_loss: 0.4518 - val_iou: 0.3709
#
# Epoch 00170: val_loss did not improve from 0.43805
# Epoch 171/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3435 - iou: 0.4725 - val_loss: 0.4250 - val_iou: 0.3848
#
# Epoch 00171: val_loss improved from 0.43805 to 0.42498, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 172/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3401 - iou: 0.4745 - val_loss: 0.4528 - val_iou: 0.3785
#
# Epoch 00172: val_loss did not improve from 0.42498
# Epoch 173/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3388 - iou: 0.4772 - val_loss: 0.4482 - val_iou: 0.3801
#
# Epoch 00173: val_loss did not improve from 0.42498
# Epoch 174/500
# 2404/2404 [==============================] - 124s 52ms/step - loss: 0.3381 - iou: 0.4764 - val_loss: 0.4484 - val_iou: 0.3801
#
# Epoch 00174: val_loss did not improve from 0.42498
# Epoch 175/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3395 - iou: 0.4757 - val_loss: 0.4359 - val_iou: 0.3814
#
# Epoch 00175: val_loss did not improve from 0.42498
# Epoch 176/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3427 - iou: 0.4739 - val_loss: 0.4271 - val_iou: 0.3919
#
# Epoch 00176: val_loss did not improve from 0.42498
# Epoch 177/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3369 - iou: 0.4770 - val_loss: 0.4394 - val_iou: 0.3888
#
# Epoch 00177: val_loss did not improve from 0.42498
# Epoch 178/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3357 - iou: 0.4790 - val_loss: 0.4364 - val_iou: 0.3878
#
# Epoch 00178: val_loss did not improve from 0.42498
# Epoch 179/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3362 - iou: 0.4788 - val_loss: 0.4386 - val_iou: 0.3863
#
# Epoch 00179: val_loss did not improve from 0.42498
# Epoch 180/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3339 - iou: 0.4807 - val_loss: 0.4378 - val_iou: 0.3791
#
# Epoch 00180: val_loss did not improve from 0.42498
# Epoch 181/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3348 - iou: 0.4815 - val_loss: 0.4332 - val_iou: 0.3950
#
# Epoch 00181: val_loss did not improve from 0.42498
# Epoch 182/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3380 - iou: 0.4785 - val_loss: 0.4414 - val_iou: 0.3864
#
# Epoch 00182: val_loss did not improve from 0.42498
# Epoch 183/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3336 - iou: 0.4822 - val_loss: 0.4423 - val_iou: 0.3865
#
# Epoch 00183: val_loss did not improve from 0.42498
# Epoch 184/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3366 - iou: 0.4788 - val_loss: 0.4425 - val_iou: 0.3931
#
# Epoch 00184: val_loss did not improve from 0.42498
# Epoch 185/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3327 - iou: 0.4823 - val_loss: 0.4372 - val_iou: 0.3887
#
# Epoch 00185: val_loss did not improve from 0.42498
# Epoch 186/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3368 - iou: 0.4787 - val_loss: 0.4386 - val_iou: 0.3785
#
# Epoch 00186: val_loss did not improve from 0.42498
# Epoch 187/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3381 - iou: 0.4782 - val_loss: 0.4350 - val_iou: 0.3878
#
# Epoch 00187: val_loss did not improve from 0.42498
# Epoch 188/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3333 - iou: 0.4832 - val_loss: 0.4374 - val_iou: 0.3977
#
# Epoch 00188: val_loss did not improve from 0.42498
# Epoch 189/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3363 - iou: 0.4798 - val_loss: 0.4356 - val_iou: 0.3927
#
# Epoch 00189: val_loss did not improve from 0.42498
# Epoch 190/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3359 - iou: 0.4810 - val_loss: 0.4363 - val_iou: 0.3875
#
# Epoch 00190: val_loss did not improve from 0.42498
# Epoch 191/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3313 - iou: 0.4857 - val_loss: 0.4290 - val_iou: 0.3906
#
# Epoch 00191: val_loss did not improve from 0.42498
# Epoch 192/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3374 - iou: 0.4800 - val_loss: 0.4431 - val_iou: 0.3856
#
# Epoch 00192: val_loss did not improve from 0.42498
# Epoch 193/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3244 - iou: 0.4908 - val_loss: 0.4298 - val_iou: 0.3867
#
# Epoch 00193: val_loss did not improve from 0.42498
# Epoch 194/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3327 - iou: 0.4837 - val_loss: 0.4303 - val_iou: 0.3922
#
# Epoch 00194: val_loss did not improve from 0.42498
# Epoch 195/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3279 - iou: 0.4880 - val_loss: 0.4330 - val_iou: 0.3996
#
# Epoch 00195: val_loss did not improve from 0.42498
# Epoch 196/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3323 - iou: 0.4850 - val_loss: 0.4410 - val_iou: 0.3797
#
# Epoch 00196: val_loss did not improve from 0.42498
# Epoch 197/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3268 - iou: 0.4895 - val_loss: 0.4443 - val_iou: 0.3877
#
# Epoch 00197: val_loss did not improve from 0.42498
# Epoch 198/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3238 - iou: 0.4920 - val_loss: 0.4249 - val_iou: 0.3956
#
# Epoch 00198: val_loss improved from 0.42498 to 0.42493, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 199/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3326 - iou: 0.4851 - val_loss: 0.4720 - val_iou: 0.3598
#
# Epoch 00199: val_loss did not improve from 0.42493
# Epoch 200/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.3303 - iou: 0.4865 - val_loss: 0.4368 - val_iou: 0.3917
#
# Epoch 00200: val_loss did not improve from 0.42493
# Epoch 201/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.3244 - iou: 0.4899 - val_loss: 0.4330 - val_iou: 0.3876
#
# Epoch 00201: val_loss did not improve from 0.42493
# Epoch 202/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3299 - iou: 0.4885 - val_loss: 0.4488 - val_iou: 0.3798
#
# Epoch 00202: val_loss did not improve from 0.42493
# Epoch 203/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3326 - iou: 0.4872 - val_loss: 0.4441 - val_iou: 0.3845
#
# Epoch 00203: val_loss did not improve from 0.42493
# Epoch 204/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3345 - iou: 0.4845 - val_loss: 0.4409 - val_iou: 0.3838
#
# Epoch 00204: val_loss did not improve from 0.42493
# Epoch 205/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3283 - iou: 0.4889 - val_loss: 0.4288 - val_iou: 0.3979
#
# Epoch 00205: val_loss did not improve from 0.42493
# Epoch 206/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3215 - iou: 0.4940 - val_loss: 0.4492 - val_iou: 0.3845
#
# Epoch 00206: val_loss did not improve from 0.42493
# Epoch 207/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3267 - iou: 0.4904 - val_loss: 0.4353 - val_iou: 0.3908
#
# Epoch 00207: val_loss did not improve from 0.42493
# Epoch 208/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3265 - iou: 0.4896 - val_loss: 0.4280 - val_iou: 0.3963
#
# Epoch 00208: val_loss did not improve from 0.42493
# Epoch 209/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3266 - iou: 0.4911 - val_loss: 0.4212 - val_iou: 0.4026
#
# Epoch 00209: val_loss improved from 0.42493 to 0.42120, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 210/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3255 - iou: 0.4917 - val_loss: 0.4286 - val_iou: 0.3977
#
# Epoch 00210: val_loss did not improve from 0.42120
# Epoch 211/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3257 - iou: 0.4919 - val_loss: 0.4180 - val_iou: 0.4124
#
# Epoch 00211: val_loss improved from 0.42120 to 0.41799, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 212/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3241 - iou: 0.4936 - val_loss: 0.4426 - val_iou: 0.3884
#
# Epoch 00212: val_loss did not improve from 0.41799
# Epoch 213/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3213 - iou: 0.4965 - val_loss: 0.4317 - val_iou: 0.3914
#
# Epoch 00213: val_loss did not improve from 0.41799
# Epoch 214/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3196 - iou: 0.4966 - val_loss: 0.4314 - val_iou: 0.3910
#
# Epoch 00214: val_loss did not improve from 0.41799
# Epoch 215/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3176 - iou: 0.4975 - val_loss: 0.4257 - val_iou: 0.3959
#
# Epoch 00215: val_loss did not improve from 0.41799
# Epoch 216/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3210 - iou: 0.4955 - val_loss: 0.4149 - val_iou: 0.4030
#
# Epoch 00216: val_loss improved from 0.41799 to 0.41489, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 217/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3232 - iou: 0.4950 - val_loss: 0.4464 - val_iou: 0.3711
#
# Epoch 00217: val_loss did not improve from 0.41489
# Epoch 218/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3192 - iou: 0.4973 - val_loss: 0.4342 - val_iou: 0.3979
#
# Epoch 00218: val_loss did not improve from 0.41489
# Epoch 219/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3239 - iou: 0.4944 - val_loss: 0.4268 - val_iou: 0.4003
#
# Epoch 00219: val_loss did not improve from 0.41489
# Epoch 220/500
# 2404/2404 [==============================] - 122s 51ms/step - loss: 0.3186 - iou: 0.4979 - val_loss: 0.4275 - val_iou: 0.3892
#
# Epoch 00220: val_loss did not improve from 0.41489
# Epoch 221/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3225 - iou: 0.4957 - val_loss: 0.4282 - val_iou: 0.4004
#
# Epoch 00221: val_loss did not improve from 0.41489
# Epoch 222/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3185 - iou: 0.4981 - val_loss: 0.4259 - val_iou: 0.3969
#
# Epoch 00222: val_loss did not improve from 0.41489
# Epoch 223/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3204 - iou: 0.4969 - val_loss: 0.4417 - val_iou: 0.3850
#
# Epoch 00223: val_loss did not improve from 0.41489
# Epoch 224/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3209 - iou: 0.4980 - val_loss: 0.4434 - val_iou: 0.3784
#
# Epoch 00224: val_loss did not improve from 0.41489
# Epoch 225/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3177 - iou: 0.4997 - val_loss: 0.4252 - val_iou: 0.4006
#
# Epoch 00225: val_loss did not improve from 0.41489
# Epoch 226/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3216 - iou: 0.4972 - val_loss: 0.4422 - val_iou: 0.3787
#
# Epoch 00226: val_loss did not improve from 0.41489
# Epoch 227/500
# 2404/2404 [==============================] - 124s 51ms/step - loss: 0.3195 - iou: 0.4988 - val_loss: 0.4301 - val_iou: 0.3996
#
# Epoch 00227: val_loss did not improve from 0.41489
# Epoch 228/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3187 - iou: 0.4994 - val_loss: 0.4405 - val_iou: 0.3882
#
# Epoch 00228: val_loss did not improve from 0.41489
# Epoch 229/500
# 2404/2404 [==============================] - 124s 51ms/step - loss: 0.3149 - iou: 0.5008 - val_loss: 0.4066 - val_iou: 0.4169
#
# Epoch 00229: val_loss improved from 0.41489 to 0.40662, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 230/500
# 2404/2404 [==============================] - 124s 51ms/step - loss: 0.3165 - iou: 0.5009 - val_loss: 0.4281 - val_iou: 0.4066
#
# Epoch 00230: val_loss did not improve from 0.40662
# Epoch 231/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3170 - iou: 0.5012 - val_loss: 0.4180 - val_iou: 0.4041
#
# Epoch 00231: val_loss did not improve from 0.40662
# Epoch 232/500
# 2404/2404 [==============================] - 124s 51ms/step - loss: 0.3163 - iou: 0.5009 - val_loss: 0.4360 - val_iou: 0.3946
#
# Epoch 00232: val_loss did not improve from 0.40662
# Epoch 233/500
# 2404/2404 [==============================] - 123s 51ms/step - loss: 0.3171 - iou: 0.5008 - val_loss: 0.4097 - val_iou: 0.4105
#
# Epoch 00233: val_loss did not improve from 0.40662
# Epoch 234/500
# 2404/2404 [==============================] - 124s 51ms/step - loss: 0.3140 - iou: 0.5019 - val_loss: 0.4198 - val_iou: 0.4053
#
# Epoch 00234: val_loss did not improve from 0.40662
# Epoch 235/500
# 2404/2404 [==============================] - 124s 51ms/step - loss: 0.3179 - iou: 0.5011 - val_loss: 0.4343 - val_iou: 0.3953
#
# Epoch 00235: val_loss did not improve from 0.40662
# Epoch 236/500
# ...
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2945 - iou: 0.5278 - val_loss: 0.4088 - val_iou: 0.4223
#
# Epoch 00336: val_loss did not improve from 0.38280
# Epoch 337/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2944 - iou: 0.5275 - val_loss: 0.4120 - val_iou: 0.4223
#
# Epoch 00337: val_loss did not improve from 0.38280
# Epoch 338/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2916 - iou: 0.5301 - val_loss: 0.3922 - val_iou: 0.4372
#
# Epoch 00338: val_loss did not improve from 0.38280
# Epoch 339/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2932 - iou: 0.5291 - val_loss: 0.3947 - val_iou: 0.4259
#
# Epoch 00339: val_loss did not improve from 0.38280
# Epoch 340/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2927 - iou: 0.5296 - val_loss: 0.4007 - val_iou: 0.4198
#
# Epoch 00340: val_loss did not improve from 0.38280
# Epoch 341/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2947 - iou: 0.5276 - val_loss: 0.4022 - val_iou: 0.4348
#
# Epoch 00341: val_loss did not improve from 0.38280
# Epoch 342/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2894 - iou: 0.5325 - val_loss: 0.4056 - val_iou: 0.4243
#
# Epoch 00342: val_loss did not improve from 0.38280
# Epoch 343/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2921 - iou: 0.5301 - val_loss: 0.3942 - val_iou: 0.4356
#
# Epoch 00343: val_loss did not improve from 0.38280
# Epoch 344/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2891 - iou: 0.5325 - val_loss: 0.3841 - val_iou: 0.4337
#
# Epoch 00344: val_loss did not improve from 0.38280
# Epoch 345/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2937 - iou: 0.5291 - val_loss: 0.4053 - val_iou: 0.4179
#
# Epoch 00345: val_loss did not improve from 0.38280
# Epoch 346/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2950 - iou: 0.5289 - val_loss: 0.4142 - val_iou: 0.4200
#
# Epoch 00346: val_loss did not improve from 0.38280
# Epoch 347/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2912 - iou: 0.5308 - val_loss: 0.3833 - val_iou: 0.4385
#
# Epoch 00347: val_loss did not improve from 0.38280
# Epoch 348/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2944 - iou: 0.5288 - val_loss: 0.4171 - val_iou: 0.4186
#
# Epoch 00348: val_loss did not improve from 0.38280
# Epoch 349/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2884 - iou: 0.5331 - val_loss: 0.4125 - val_iou: 0.4160
#
# Epoch 00349: val_loss did not improve from 0.38280
# Epoch 350/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2902 - iou: 0.5325 - val_loss: 0.4039 - val_iou: 0.4118
#
# Epoch 00350: val_loss did not improve from 0.38280
# Epoch 351/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2872 - iou: 0.5338 - val_loss: 0.3990 - val_iou: 0.4310
#
# Epoch 00351: val_loss did not improve from 0.38280
# Epoch 352/500
# 2404/2404 [==============================] - 121s 51ms/step - loss: 0.2950 - iou: 0.5285 - val_loss: 0.4133 - val_iou: 0.4178
#
# Epoch 00352: val_loss did not improve from 0.38280
# Epoch 353/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2914 - iou: 0.5316 - val_loss: 0.3957 - val_iou: 0.4313
#
# Epoch 00353: val_loss did not improve from 0.38280
# Epoch 354/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2887 - iou: 0.5325 - val_loss: 0.3860 - val_iou: 0.4353
#
# Epoch 00354: val_loss did not improve from 0.38280
# Epoch 355/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2901 - iou: 0.5326 - val_loss: 0.4001 - val_iou: 0.4256
#
# Epoch 00355: val_loss did not improve from 0.38280
# Epoch 356/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2904 - iou: 0.5321 - val_loss: 0.4035 - val_iou: 0.4293
#
# Epoch 00356: val_loss did not improve from 0.38280
# Epoch 357/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2914 - iou: 0.5316 - val_loss: 0.3904 - val_iou: 0.4346
#
# Epoch 00357: val_loss did not improve from 0.38280
# Epoch 358/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2907 - iou: 0.5328 - val_loss: 0.3702 - val_iou: 0.4548
#
# Epoch 00358: val_loss improved from 0.38280 to 0.37019, saving model to E:/Deep Course/Weeks/W10/Models\model-200MC.h5
# Epoch 359/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2886 - iou: 0.5350 - val_loss: 0.4151 - val_iou: 0.4176
#
# Epoch 00359: val_loss did not improve from 0.37019
# Epoch 360/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2908 - iou: 0.5320 - val_loss: 0.4120 - val_iou: 0.4186
#
# Epoch 00360: val_loss did not improve from 0.37019
# Epoch 361/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2915 - iou: 0.5309 - val_loss: 0.3774 - val_iou: 0.4521
#
# Epoch 00361: val_loss did not improve from 0.37019
# Epoch 362/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2915 - iou: 0.5320 - val_loss: 0.3889 - val_iou: 0.4423
#
# Epoch 00362: val_loss did not improve from 0.37019
# Epoch 363/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2897 - iou: 0.5344 - val_loss: 0.3965 - val_iou: 0.4363
#
# Epoch 00363: val_loss did not improve from 0.37019
# Epoch 364/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2894 - iou: 0.5342 - val_loss: 0.4132 - val_iou: 0.4156
#
# Epoch 00364: val_loss did not improve from 0.37019
# Epoch 365/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2913 - iou: 0.5324 - val_loss: 0.4095 - val_iou: 0.4123
#
# Epoch 00365: val_loss did not improve from 0.37019
# Epoch 366/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2888 - iou: 0.5344 - val_loss: 0.3976 - val_iou: 0.4311
#
# Epoch 00366: val_loss did not improve from 0.37019
# Epoch 367/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2890 - iou: 0.5352 - val_loss: 0.3796 - val_iou: 0.4387
#
# Epoch 00367: val_loss did not improve from 0.37019
# Epoch 368/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2873 - iou: 0.5359 - val_loss: 0.3936 - val_iou: 0.4362
#
# Epoch 00368: val_loss did not improve from 0.37019
# Epoch 369/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2885 - iou: 0.5362 - val_loss: 0.4125 - val_iou: 0.4137
#
# Epoch 00369: val_loss did not improve from 0.37019
# Epoch 370/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2868 - iou: 0.5363 - val_loss: 0.3989 - val_iou: 0.4254
#
# Epoch 00370: val_loss did not improve from 0.37019
# Epoch 371/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2844 - iou: 0.5386 - val_loss: 0.3827 - val_iou: 0.4469
#
# Epoch 00371: val_loss did not improve from 0.37019
# Epoch 372/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2892 - iou: 0.5339 - val_loss: 0.4013 - val_iou: 0.4353
#
# Epoch 00372: val_loss did not improve from 0.37019
# Epoch 373/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2897 - iou: 0.5330 - val_loss: 0.4044 - val_iou: 0.4238
#
# Epoch 00373: val_loss did not improve from 0.37019
# Epoch 374/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2864 - iou: 0.5382 - val_loss: 0.3906 - val_iou: 0.4373
#
# Epoch 00374: val_loss did not improve from 0.37019
# Epoch 375/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2868 - iou: 0.5355 - val_loss: 0.3985 - val_iou: 0.4287
#
# Epoch 00375: val_loss did not improve from 0.37019
# Epoch 376/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2831 - iou: 0.5398 - val_loss: 0.3978 - val_iou: 0.4291
#
# Epoch 00376: val_loss did not improve from 0.37019
# Epoch 377/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2880 - iou: 0.5356 - val_loss: 0.4213 - val_iou: 0.4062
#
# Epoch 00377: val_loss did not improve from 0.37019
# Epoch 378/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2897 - iou: 0.5334 - val_loss: 0.3963 - val_iou: 0.4313
#
# Epoch 00378: val_loss did not improve from 0.37019
# Epoch 379/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2815 - iou: 0.5418 - val_loss: 0.3920 - val_iou: 0.4373
#
# Epoch 00379: val_loss did not improve from 0.37019
# Epoch 380/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2865 - iou: 0.5374 - val_loss: 0.3952 - val_iou: 0.4281
#
# Epoch 00380: val_loss did not improve from 0.37019
# Epoch 381/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2881 - iou: 0.5351 - val_loss: 0.4051 - val_iou: 0.4186
#
# Epoch 00381: val_loss did not improve from 0.37019
# Epoch 382/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2858 - iou: 0.5364 - val_loss: 0.4114 - val_iou: 0.4188
#
# Epoch 00382: val_loss did not improve from 0.37019
# Epoch 383/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2846 - iou: 0.5399 - val_loss: 0.4168 - val_iou: 0.4180
#
# Epoch 00383: val_loss did not improve from 0.37019
# Epoch 384/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2811 - iou: 0.5420 - val_loss: 0.4029 - val_iou: 0.4276
#
# Epoch 00384: val_loss did not improve from 0.37019
# Epoch 385/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2839 - iou: 0.5386 - val_loss: 0.3861 - val_iou: 0.4417
#
# Epoch 00385: val_loss did not improve from 0.37019
# Epoch 386/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2869 - iou: 0.5368 - val_loss: 0.4071 - val_iou: 0.4235
#
# Epoch 00386: val_loss did not improve from 0.37019
# Epoch 387/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2873 - iou: 0.5351 - val_loss: 0.3886 - val_iou: 0.4324
#
# Epoch 00387: val_loss did not improve from 0.37019
# Epoch 388/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2863 - iou: 0.5380 - val_loss: 0.3924 - val_iou: 0.4317
#
# Epoch 00388: val_loss did not improve from 0.37019
# Epoch 389/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2838 - iou: 0.5402 - val_loss: 0.3887 - val_iou: 0.4327
#
# Epoch 00389: val_loss did not improve from 0.37019
# Epoch 390/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2862 - iou: 0.5371 - val_loss: 0.3977 - val_iou: 0.4318
#
# Epoch 00390: val_loss did not improve from 0.37019
# Epoch 391/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2889 - iou: 0.5357 - val_loss: 0.3996 - val_iou: 0.4319
#
# Epoch 00391: val_loss did not improve from 0.37019
# Epoch 392/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2858 - iou: 0.5388 - val_loss: 0.3903 - val_iou: 0.4329
#
# Epoch 00392: val_loss did not improve from 0.37019
# Epoch 393/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2875 - iou: 0.5358 - val_loss: 0.3973 - val_iou: 0.4304
#
# Epoch 00393: val_loss did not improve from 0.37019
# Epoch 394/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2839 - iou: 0.5402 - val_loss: 0.3967 - val_iou: 0.4229
#
# Epoch 00394: val_loss did not improve from 0.37019
# Epoch 395/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2863 - iou: 0.5387 - val_loss: 0.3982 - val_iou: 0.4271
#
# Epoch 00395: val_loss did not improve from 0.37019
# Epoch 396/500
# 2404/2404 [==============================] - 121s 50ms/step - loss: 0.2861 - iou: 0.5392 - val_loss: 0.4025 - val_iou: 0.4336
#
# Epoch 00396: val_loss did not improve from 0.37019
# Epoch 397/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2827 - iou: 0.5406 - val_loss: 0.4229 - val_iou: 0.4108
#
# Epoch 00397: val_loss did not improve from 0.37019
# Epoch 398/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2812 - iou: 0.5434 - val_loss: 0.3860 - val_iou: 0.4365
#
# Epoch 00398: val_loss did not improve from 0.37019
# Epoch 399/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2862 - iou: 0.5378 - val_loss: 0.3904 - val_iou: 0.4384
#
# Epoch 00399: val_loss did not improve from 0.37019
# Epoch 400/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2834 - iou: 0.5400 - val_loss: 0.4071 - val_iou: 0.4226
#
# Epoch 00400: val_loss did not improve from 0.37019
# Epoch 401/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2918 - iou: 0.5344 - val_loss: 0.3810 - val_iou: 0.4447
#
# Epoch 00401: val_loss did not improve from 0.37019
# Epoch 402/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2856 - iou: 0.5382 - val_loss: 0.4066 - val_iou: 0.4240
#
# Epoch 00402: val_loss did not improve from 0.37019
# Epoch 403/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2844 - iou: 0.5394 - val_loss: 0.3952 - val_iou: 0.4253
#
# Epoch 00403: val_loss did not improve from 0.37019
# Epoch 404/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2838 - iou: 0.5420 - val_loss: 0.3998 - val_iou: 0.4348
#
# Epoch 00404: val_loss did not improve from 0.37019
# Epoch 405/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2818 - iou: 0.5433 - val_loss: 0.4081 - val_iou: 0.4211
#
# Epoch 00405: val_loss did not improve from 0.37019
# Epoch 406/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2809 - iou: 0.5443 - val_loss: 0.4070 - val_iou: 0.4140
#
# Epoch 00406: val_loss did not improve from 0.37019
# Epoch 407/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2848 - iou: 0.5410 - val_loss: 0.4180 - val_iou: 0.4161
#
# Epoch 00407: val_loss did not improve from 0.37019
# Epoch 408/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2856 - iou: 0.5400 - val_loss: 0.4290 - val_iou: 0.4025
#
# Epoch 00408: val_loss did not improve from 0.37019
# Epoch 409/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2817 - iou: 0.5422 - val_loss: 0.3852 - val_iou: 0.4337
#
# Epoch 00409: val_loss did not improve from 0.37019
# Epoch 410/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2862 - iou: 0.5391 - val_loss: 0.3936 - val_iou: 0.4396
#
# Epoch 00410: val_loss did not improve from 0.37019
# Epoch 411/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2835 - iou: 0.5406 - val_loss: 0.3886 - val_iou: 0.4349
#
# Epoch 00411: val_loss did not improve from 0.37019
# Epoch 412/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2843 - iou: 0.5418 - val_loss: 0.3940 - val_iou: 0.4312
#
# Epoch 00412: val_loss did not improve from 0.37019
# Epoch 413/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2792 - iou: 0.5440 - val_loss: 0.4149 - val_iou: 0.4181
#
# Epoch 00413: val_loss did not improve from 0.37019
# Epoch 414/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2812 - iou: 0.5430 - val_loss: 0.4229 - val_iou: 0.4034
#
# Epoch 00414: val_loss did not improve from 0.37019
# Epoch 415/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2839 - iou: 0.5411 - val_loss: 0.4066 - val_iou: 0.4258
#
# Epoch 00415: val_loss did not improve from 0.37019
# Epoch 416/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2803 - iou: 0.5453 - val_loss: 0.3771 - val_iou: 0.4527
#
# Epoch 00416: val_loss did not improve from 0.37019
# Epoch 417/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2813 - iou: 0.5438 - val_loss: 0.3942 - val_iou: 0.4338
#
# Epoch 00417: val_loss did not improve from 0.37019
# Epoch 418/500
# 2404/2404 [==============================] - 120s 50ms/step - loss: 0.2782 - iou: 0.5464 - val_loss: 0.3817 - val_iou: 0.4390
#
# Epoch 00418: val_loss did not improve from 0.37019
